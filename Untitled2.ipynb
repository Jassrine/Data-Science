# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/ecommerce_transactions.csv")
print(df.head())
print(df.info())
print(df.describe())
print(df.isnull().sum())
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
plt.figure(figsize=(5,4))
df['Product'].value_counts().plot(kind='bar', color='teal')
plt.title("Product Frequency")
plt.xlabel("Product")
plt.ylabel("Count")
plt.show()
plt.figure(figsize=(6,4))
plt.plot(df['OrderDate'], df['Sales'], marker='o')
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/ecommerce_transactions.csv")
print(df)
# Out:
#        Transaction_ID           User_Name  Age    Country Product_Category  \
# 0                   1            Ava Hall   63     Mexico         Clothing
# 1                   2         Sophia Hall   59      India           Beauty
# 2                   3     Elijah Thompson   26     France            Books
# 3                   4        Elijah White   43     Mexico           Sports
# 4                   5          Ava Harris   48    Germany           Beauty
# ...               ...                 ...  ...        ...              ...
# 49995           49996  Isabella Rodriguez   53      India      Electronics
# 49996           49997           Emma Hall   30     France   Home & Kitchen
# 49997           49998      Isabella Allen   50  Australia           Beauty
# 49998           49999        Olivia Clark   48  Australia          Grocery
# 49999           50000       Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/ecommerce_transactions.csv")
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])
plt.figure(figsize=(10,10))
plt.plot(df['Transaction_Date'], df['Purchase_Amount'], marker='o')
plt.xlabel('Date')
plt.ylabel('Purchase Amount')
plt.title('Sales Over Time')
plt.grid(True)
plt.show()
plt.figure(figsize=(6,4))
df['Product_Category'].value_counts().plot(kind='bar')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.title('Product Category Distribution')
plt.grid(True, axis='y')
plt.show()
plt.figure(figsize=(6,4))
df.groupby('Country')['Purchase_Amount'].sum().plot(kind='bar')
plt.xlabel("Country")
plt.ylabel("Total Sales")
plt.title("Sales by Country")
plt.grid(True, axis='y')
plt.show()
plt.figure(figsize=(6,4))
plt.hist(df['Age'], bins=20, edgecolor='black')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution")
plt.grid(True)

plt.show()

# %%
# !pip install numpy
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
y_2018 = pd.read_csv("/customer_analytics_dataset.csv")
data = pd.concat([y_2018],sort=False)
data
# Out:
# ...
#      customer_id  age  gender    country  avg_order_value  total_orders  \
# 0      CUST_8270   30  Female     Brazil           101.08             8
# 1      CUST_1860   53  Female        USA            90.39            10
# 2      CUST_6390   73    Male  Australia            83.28             6
# 3      CUST_6191   30   Other      Japan           109.90             9
# 4      CUST_6734   29  Female     Canada           269.38            16
# ...          ...  ...     ...        ...              ...           ...
# 4995   CUST_8533   49  Female         UK           132.16             9
# 4996   CUST_5616   23  Female         UK            47.81            10
# 4997   CUST_2140   79    Male      Japan           224.97            16
# 4998   CUST_6730   62    Male        USA           220.33             8
# 4999   CUST_8465   38    Male     Canada            75.57             6
#
#       last_purchase  is_fraudulent preferred_category  email_open_rate  \
# ...
